# %%
import pandas as pd
import matplotlib.pyplot as plt

BASE_DIR = "/beegfs/scratch/ric.broccoli/kubacki.michal/SRF_MeCP2_CUTandTAG/iterative_alternative"
RUN_NAME = "cpg_enrichment_2_rep_in_peaks"

# Set pandas display options to show all columns without wrapping
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', None)        # Don't wrap wide DataFrames
pd.set_option('display.max_colwidth', None) # Don't truncate column contents

# %%
# Load the CpG enrichment results
cpg_enrichment_df = pd.read_csv(f"{BASE_DIR}/results/no_dedup/cpg_enrichment/NSC/broad/{RUN_NAME}/cpg_enrichment_parallel.csv")

# %%
# Display first few rows and basic info
print("DataFrame shape:", cpg_enrichment_df.shape)
print("\nFirst few rows:")
display(cpg_enrichment_df.head())
print("\nColumn names:")
print(cpg_enrichment_df.columns.tolist())
# Out:
# DataFrame shape: (12829, 23)
#
# First few rows:
#     chr    start      end  exo_signal  endo_signal  enrichment  pvalue  \
# 0  chr1  3671654  3672156   15.331182     5.965003    2.570188     0.1
# 1  chr1  4491701  4493673    8.716315    10.776053    0.808860     1.0
# 2  chr1  4571641  4572075   25.026296     0.076022  329.197490     0.5
# 3  chr1  4785376  4785814   25.444773    24.523792    1.037555     1.0
# 4  chr1  4807559  4808103   18.253522     5.436937    3.357317     0.1
#
#   binding_type  significant  exo_replicates_with_signal  \
# 0         both        False                           3
# 1         both        False                           2
# 2         both        False                           3
# 3         both        False                           3
# 4         both        False                           3
#
#    endo_replicates_with_signal  \
# 0                            3
# 1                            2
# 2                            1
# 3                            3
# 4                            3
#
#                                       exo_replicate_signals  \
# 0  14.398215172280159,21.305724717144454,10.289605426735111
# 1                 12.917271586025462,0.0,13.231673493104822
# 2  30.021045078151403,13.556918122386204,31.500924768035347
# 3    43.13485337533006,25.311575742503305,7.887889002847865
# 4    13.67224773939918,13.221223759008389,27.86709427862775
#
#                                     endo_replicate_signals  region_length  \
# 0  10.282046731029238,6.968618375914438,0.6443446448871067           1792
# 1                 0.0,27.234050478654748,5.094107347376206           1360
# 2                              0.22806640496387434,0.0,0.0            786
# 3   36.00965611506565,11.335664996729886,26.22605557141936           2211
# 4    8.57153564399364,1.2887255350748699,6.450549572998402           3264
#
#    cpg_length cpg_score  cpg_name  exo_replicates_with_peaks  \
# 0         502      CpG:       613                          2
# 1        1972      CpG:       619                          2
# 2         434      CpG:       619                          3
# 3         438      CpG:       621                          3
# 4         544      CpG:       621                          3
#
#    endo_replicates_with_peaks   exo_peak_scores_by_rep  \
# 0                           0          5.54931;6.06037
# 1                           1            6.0982;5.8282
# 2                           0  4.35039;6.82732;3.40697
# 3                           3   2.96862;6.6373;7.27926
# 4                           1  4.55161;7.91139;6.13029
#
#    endo_peak_scores_by_rep  region_start  region_end
# 0                      NaN       3670396     3672188
# 1                   4.1282       4492093     4493453
# 2                      NaN       4571438     4572224
# 3  12.2007;6.57158;5.01142       4784061     4786272
# 4                  3.25084       4806809     4810073
# Column names:
# ['chr', 'start', 'end', 'exo_signal', 'endo_signal', 'enrichment', 'pvalue', 'binding_type', 'significant', 'exo_replicates_with_signal', 'endo_replicates_with_signal', 'exo_replicate_signals', 'endo_replicate_signals', 'region_length', 'cpg_length', 'cpg_score', 'cpg_name', 'exo_replicates_with_peaks', 'endo_replicates_with_peaks', 'exo_peak_scores_by_rep', 'endo_peak_scores_by_rep', 'region_start', 'region_end']

# %%
# Sort the DataFrame by enrichment value in descending order
cpg_enrichment_df_sorted = cpg_enrichment_df.sort_values(by='enrichment', ascending=False)

# Display first few rows of sorted DataFrame
print("Top enriched CpG islands:")
display(cpg_enrichment_df_sorted.head())
# Out:
# Top enriched CpG islands:
#          chr      start        end  exo_signal  endo_signal  enrichment  \
# 6085   chr19   44734343   44735056   15.453329          0.0         inf
# 3330   chr13   96748199   96748403   33.173716          0.0         inf
# 12797   chrX  159414230  159415517   15.982540          0.0         inf
# 12819   chrX  168122986  168123301   17.661884          0.0         inf
# 5293   chr17   68003884   68004335   52.088128          0.0         inf
#
#        pvalue binding_type  significant  exo_replicates_with_signal  \
# 6085      1.0     exo_only        False                           2
# 3330      1.0     exo_only        False                           2
# 12797     1.0     exo_only        False                           3
# 12819     1.0     exo_only        False                           2
# 5293      1.0     exo_only        False                           3
#
#        endo_replicates_with_signal  \
# 6085                             0
# 3330                             0
# 12797                            0
# 12819                            0
# 5293                             0
#
#                                          exo_replicate_signals  \
# 6085                   0.0,8.257254110088892,38.10273315233162
# 3330                   55.65521597415767,43.86593215027998,0.0
# 12797    6.530822352008576,12.00851120687891,29.40828514321164
# 12819                 29.36382449578945,23.621828120347168,0.0
# 5293   58.904634082973196,22.413534491579124,74.94621410184693
#
#       endo_replicate_signals  region_length  cpg_length cpg_score  cpg_name  \
# 6085             0.0,0.0,0.0           1087         713      CpG:       926
# 3330             0.0,0.0,0.0            267         204      CpG:      1323
# 12797            0.0,0.0,0.0            859        1287      CpG:      1801
# 12819            0.0,0.0,0.0            974         315      CpG:      1867
# 5293             0.0,0.0,0.0            309         451      CpG:      1103
#
#        exo_replicates_with_peaks  endo_replicates_with_peaks  \
# 6085                           2                           0
# 3330                           2                           0
# 12797                          2                           0
# 12819                          2                           0
# 5293                           2                           0
#
#       exo_peak_scores_by_rep endo_peak_scores_by_rep  region_start  region_end
# 6085         6.33438;4.07766                     NaN      44734499    44735586
# 3330         5.32714;4.40742                     NaN      96748259    96748526
# 12797        3.18458;3.75447                     NaN     159413536   159414395
# 12819        3.28488;4.05905                     NaN     168122898   168123872
# 5293         7.68799;2.60943                     NaN      68004184    68004493

# %%
# Split data based on binding type
exo_only_df = cpg_enrichment_df[cpg_enrichment_df['binding_type'] == 'exo_only']
endo_only_df = cpg_enrichment_df[cpg_enrichment_df['binding_type'] == 'endo_only'] 
both_df = cpg_enrichment_df[cpg_enrichment_df['binding_type'] == 'both']

# Print sizes of each group
print(f"Number of CpG islands bound by exo only: {len(exo_only_df)}")
print(f"Number of CpG islands bound by endo only: {len(endo_only_df)}")
print(f"Number of CpG islands bound by both: {len(both_df)}")
# Out:
# Number of CpG islands bound by exo only: 30
# Number of CpG islands bound by endo only: 1
# Number of CpG islands bound by both: 12798

# %%
print("both_df['enrichment']")
print(both_df['enrichment'])
# Out:
# both_df['enrichment']
# 0          2.570188
# 1          0.808860
# 2        329.197490
# 3          1.037555
# 4          3.357317
#             ...
# 12824      0.011030
# 12825      1.446341
# 12826      0.945502
# 12827      0.159034
# 12828      0.770043
# Name: enrichment, Length: 12798, dtype: float64

# %%
# Create histogram of enrichment values for regions bound by both
plt.figure(figsize=(10, 6))

# Plot histogram with better binning and transparency
# Calculate reasonable range based on data distribution
q1, q3 = both_df['enrichment'].quantile([0.25, 0.75])
factor = 3
iqr = q3 - q1
range_min = max(0, q1 - factor * iqr)  # Don't go below 0 for enrichment
range_max = q3 + factor * iqr

# Plot histogram and get the axis object
n, bins, patches = plt.hist(both_df['enrichment'], bins=50, edgecolor='black', alpha=0.7,
                          color='#2196F3', density=False, range=(range_min, range_max))

# Add grid for better readability
plt.grid(True, alpha=0.3)

# Improve axis labels and title
plt.xlabel('Enrichment Score', fontsize=12)
plt.ylabel('Number of Regions', fontsize=12)
plt.title('Distribution of Enrichment Values\nin Regions Bound by Both ExoC and EndoC',
          fontsize=14, pad=15)

# Add vertical line at enrichment = 1
plt.axvline(x=1, color='red', linestyle='--', linewidth=2,
            label='Enrichment = 1 (No difference)')

# Set x-axis limits based on the actual data range
plt.xlim(range_min, range_max)

# Add legend with better positioning
plt.legend(loc='upper right')

# Adjust layout to prevent label cutoff
plt.tight_layout()

plt.show()

# %%
# Print summary statistics of enrichment values
print("Summary statistics of enrichment values:")
print(both_df['enrichment'].describe())

# Find outliers (values > range_max)
outliers_df = both_df[both_df['enrichment'] > range_max].copy()
outliers_df = outliers_df.sort_values('enrichment', ascending=False)

print(f"\nNumber of outliers (enrichment > {range_max}):", len(outliers_df))
print("\nTop 10 outliers by enrichment value:")
print(outliers_df[['chr', 'start', 'end', 'cpg_length', 'enrichment']].head(10))

# Create box plot to visualize distribution and outliers
plt.figure(figsize=(10, 6))
# The whis parameter controls the whisker length in the boxplot
# whis=factor means whiskers extend to points within factor * IQR of Q1/Q3
# Points beyond the whiskers are considered outliers and plotted individually
plt.boxplot(both_df['enrichment'], whis=factor)
plt.ylabel('Enrichment Score', fontsize=12)
plt.title('Box Plot of Enrichment Values\nShowing Distribution and Outliers',
          fontsize=14, pad=15)
plt.grid(True, alpha=0.3)

# Add horizontal line at enrichment = 1
plt.axhline(y=1, color='red', linestyle='--', linewidth=2,
            label='Enrichment = 1 (No difference)')

plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Summary statistics of enrichment values:
# count    12798.000000
# mean         2.004450
# std          7.330297
# min          0.000794
# 25%          1.005493
# 50%          1.379874
# 75%          1.916173
# max        497.676069
# Name: enrichment, dtype: float64
#
# Number of outliers (enrichment > 4.648209837915454): 443
#
# Top 10 outliers by enrichment value:
#          chr      start        end  cpg_length  enrichment
# 11505   chr8   87038039   87038387         348  497.676069
# 2       chr1    4571641    4572075         434  329.197490
# 11533   chr8   92855270   92855643         373  240.599851
# 8514    chr4  140515036  140515425         389  168.913028
# 6419    chr2   31845689   31846926        1237  167.649089
# 3248   chr13   73271873   73272236         363  156.624901
# 3833   chr14  122912883  122913319         436  152.667024
# 8041    chr4   65124446   65124914         468  145.519579
# 3355   chr13  100551632  100552839        1207  136.173064
# 11643   chr8  110079697  110080128         431  120.035254

# %%
# Create histogram of region_length values for regions bound by both
plt.figure(figsize=(10, 6))

# Plot histogram with better binning and transparency
# Calculate reasonable range based on data distribution
q1, q3 = both_df['region_length'].quantile([0.25, 0.75])
factor = 3
iqr = q3 - q1
range_min = max(0, q1 - factor * iqr)  # Don't go below 0 for region_length
range_max = q3 + factor * iqr

# Plot histogram and get the axis object
n, bins, patches = plt.hist(both_df['region_length'], bins=50, edgecolor='black', alpha=0.7,
                          color='#2196F3', density=False, range=(range_min, range_max),
                          label='Region Length Distribution')

# Add grid for better readability
plt.grid(True, alpha=0.3)

# Improve axis labels and title
plt.xlabel('Region Length (bp)', fontsize=12)
plt.ylabel('Number of Regions', fontsize=12)
plt.title('Distribution of Region Lengths',
          fontsize=14, pad=15)

# Set x-axis limits based on the actual data range
plt.xlim(range_min, range_max)

# Add legend with better positioning
plt.legend(loc='upper right')

# Adjust layout to prevent label cutoff
plt.tight_layout()
plt.show()

# %%
exo_only_df
# Out:
#          chr      start        end  exo_signal  endo_signal  enrichment  \
# 10      chr1    6359082    6359442   39.527656          0.0         inf
# 41      chr1   17091517   17091971   18.636133          0.0         inf
# 869    chr10   52027445   52028039   21.626241          0.0         inf
# 923    chr10   62110704   62111095    7.380919          0.0         inf
# 1187   chr10   88885817   88886555   29.082964          0.0         inf
# 2607   chr12   55861029   55861241   13.110949          0.0         inf
# 2862   chr12  110277822  110279918   20.173739          0.0         inf
# 3330   chr13   96748199   96748403   33.173716          0.0         inf
# 3996   chr15   73058048   73058500   30.978179          0.0         inf
# 4280   chr15   97323527   97323768   13.877522          0.0         inf
# 4381   chr15  102981650  102982309   12.301058          0.0         inf
# 5293   chr17   68003884   68004335   52.088128          0.0         inf
# 5979   chr19   24999191   24999943   16.564967          0.0         inf
# 6085   chr19   44734343   44735056   15.453329          0.0         inf
# 6244    chr2   16356320   16356831   35.782316          0.0         inf
# 6595    chr2   74711842   74712395   29.478870          0.0         inf
# 6895    chr2  131171499  131171740   23.184505          0.0         inf
# 7275    chr3   27371767   27372546   30.503059          0.0         inf
# 8072    chr4   87230147   87230588   20.072936          0.0         inf
# 8510    chr4  139823597  139824241    9.734732          0.0         inf
# 9181    chr5  119670093  119671401   11.763857          0.0         inf
# 9294    chr5  131439468  131439909    9.785768          0.0         inf
# 9711    chr6   65381245   65381614   13.924254          0.0         inf
# 9745    chr6   77243659   77244825   11.902804          0.0         inf
# 11632   chr8  108950855  108951192   16.978245          0.0         inf
# 12296   chr9   98601375   98601757   33.612730          0.0         inf
# 12510   chr9  123678266  123678959   10.991180          0.0         inf
# 12612   chrX   52744262   52744655   25.297592          0.0         inf
# 12797   chrX  159414230  159415517   15.982540          0.0         inf
# 12819   chrX  168122986  168123301   17.661884          0.0         inf
#
#        pvalue binding_type  significant  exo_replicates_with_signal  \
# 10        1.0     exo_only        False                           2
# 41        1.0     exo_only        False                           2
# 869       1.0     exo_only        False                           2
# 923       1.0     exo_only        False                           2
# 1187      1.0     exo_only        False                           3
# 2607      1.0     exo_only        False                           2
# 2862      1.0     exo_only        False                           3
# 3330      1.0     exo_only        False                           2
# 3996      1.0     exo_only        False                           2
# 4280      1.0     exo_only        False                           2
# 4381      1.0     exo_only        False                           2
# 5293      1.0     exo_only        False                           3
# 5979      1.0     exo_only        False                           3
# 6085      1.0     exo_only        False                           2
# 6244      1.0     exo_only        False                           3
# 6595      1.0     exo_only        False                           3
# 6895      1.0     exo_only        False                           2
# 7275      1.0     exo_only        False                           2
# 8072      1.0     exo_only        False                           3
# 8510      1.0     exo_only        False                           3
# 9181      1.0     exo_only        False                           3
# 9294      1.0     exo_only        False                           2
# 9711      1.0     exo_only        False                           3
# 9745      1.0     exo_only        False                           3
# 11632     1.0     exo_only        False                           3
# 12296     1.0     exo_only        False                           3
# 12510     1.0     exo_only        False                           2
# 12612     1.0     exo_only        False                           2
# 12797     1.0     exo_only        False                           3
# 12819     1.0     exo_only        False                           2
#
#        endo_replicates_with_signal  \
# 10                               0
# 41                               0
# 869                              0
# 923                              0
# 1187                             0
# 2607                             0
# 2862                             0
# 3330                             0
# 3996                             0
# 4280                             0
# 4381                             0
# 5293                             0
# 5979                             0
# 6085                             0
# 6244                             0
# 6595                             0
# 6895                             0
# 7275                             0
# 8072                             0
# 8510                             0
# 9181                             0
# 9294                             0
# 9711                             0
# 9745                             0
# 11632                            0
# 12296                            0
# 12510                            0
# 12612                            0
# 12797                            0
# 12819                            0
#
#                                           exo_replicate_signals  \
# 10                     98.53909743704448,0.0,20.043869983859178
# 41                      18.06756362446978,0.0,37.84083460916364
# 869                    15.586902245115011,0.0,49.29182075842833
# 923                   11.128808062873896,11.013947671685957,0.0
# 1187    1.105192514796242,62.510802409491944,23.632896142319826
# 2607                  26.489604731590358,0.0,12.843241765203418
# 2862   30.898792043240938,13.761582547866446,15.860841109352961
# 3330                    55.65521597415767,43.86593215027998,0.0
# 3996                    40.12861853783616,52.80591918342382,0.0
# 4280                  16.913849355051756,0.0,24.718716629808753
# 4381                   0.0,8.565320756289989,28.337853076266413
# 5293    58.904634082973196,22.413534491579124,74.94621410184693
# 5979      20.64143014905662,9.245668528697102,19.80780160658172
# 6085                    0.0,8.257254110088892,38.10273315233162
# 6244     45.315392376389774,47.54456562561641,14.48698864206739
# 6595    31.637424529419786,10.283417851471704,46.51576838217491
# 6895                   0.0,46.13644729184983,23.417067978997974
# 7275                      0.0,65.4717836406869,26.0373923395721
# 8072      32.90755009651184,21.89901989104322,5.412236513469984
# 8510     13.781309453023743,6.058647190920219,9.364239336708174
# 9181   11.716856885160137,12.672939920017862,10.901774434961824
# 9294                   18.58471176677817,0.0,10.772592045965617
# 9711   28.357874949266957,12.769005043491436,0.6458832843668142
# 9745   12.716282966889834,6.7332975762455085,16.258831466499128
# 11632   31.53246210387186,7.8724721882194935,11.529799801234851
# 12296     25.99366189570328,18.48084050198301,56.36368894805178
# 12510                   19.50161598824166,0.0,13.47192349539342
# 12612                  31.297435817428678,44.59534071219813,0.0
# 12797     6.530822352008576,12.00851120687891,29.40828514321164
# 12819                  29.36382449578945,23.621828120347168,0.0
#
#       endo_replicate_signals  region_length  cpg_length cpg_score  cpg_name  \
# 10               0.0,0.0,0.0            328         360      CpG:       633
# 41               0.0,0.0,0.0           1467         454      CpG:       715
# 869              0.0,0.0,0.0            624         594      CpG:       981
# 923              0.0,0.0,0.0           1223         391      CpG:      1058
# 1187             0.0,0.0,0.0            319         738      CpG:      1263
# 2607             0.0,0.0,0.0           1153         212      CpG:      1011
# 2862             0.0,0.0,0.0           1706        2096      CpG:      1426
# 3330             0.0,0.0,0.0            267         204      CpG:      1323
# 3996             0.0,0.0,0.0            658         452      CpG:      1142
# 4280             0.0,0.0,0.0            567         241      CpG:      1327
# 4381             0.0,0.0,0.0           1033         659      CpG:      1370
# 5293             0.0,0.0,0.0            309         451      CpG:      1103
# 5979             0.0,0.0,0.0            877         752      CpG:       775
# 6085             0.0,0.0,0.0           1087         713      CpG:       926
# 6244             0.0,0.0,0.0           1109         511      CpG:       709
# 6595             0.0,0.0,0.0            726         553      CpG:      1155
# 6895             0.0,0.0,0.0            391         241      CpG:      1585
# 7275             0.0,0.0,0.0            355         779      CpG:       793
# 8072             0.0,0.0,0.0            913         441      CpG:      1250
# 8510             0.0,0.0,0.0           1085         644      CpG:      1651
# 9181             0.0,0.0,0.0           2340        1308      CpG:      1498
# 9294             0.0,0.0,0.0           1381         441      CpG:      1587
# 9711             0.0,0.0,0.0           1256         369      CpG:      1083
# 9745             0.0,0.0,0.0           1216        1166      CpG:      1174
# 11632            0.0,0.0,0.0           1591         337      CpG:      1416
# 12296            0.0,0.0,0.0            627         382      CpG:      1337
# 12510            0.0,0.0,0.0            814         693      CpG:      1528
# 12612            0.0,0.0,0.0            691         393      CpG:       987
# 12797            0.0,0.0,0.0            859        1287      CpG:      1801
# 12819            0.0,0.0,0.0            974         315      CpG:      1867
#
#        exo_replicates_with_peaks  endo_replicates_with_peaks  \
# 10                             2                           0
# 41                             2                           0
# 869                            2                           0
# 923                            2                           0
# 1187                           2                           0
# 2607                           2                           0
# 2862                           2                           0
# 3330                           2                           0
# 3996                           2                           0
# 4280                           2                           0
# 4381                           2                           0
# 5293                           2                           0
# 5979                           2                           0
# 6085                           2                           0
# 6244                           2                           0
# 6595                           3                           0
# 6895                           2                           0
# 7275                           2                           0
# 8072                           2                           0
# 8510                           3                           0
# 9181                           3                           0
# 9294                           2                           0
# 9711                           2                           0
# 9745                           3                           0
# 11632                          2                           0
# 12296                          2                           0
# 12510                          2                           0
# 12612                          2                           0
# 12797                          2                           0
# 12819                          2                           0
#
#         exo_peak_scores_by_rep endo_peak_scores_by_rep  region_start  \
# 10             2.38625;9.47173                     NaN       6359199
# 41             5.67863;7.84621                     NaN      17090590
# 869            6.36741;2.97735                     NaN      52027146
# 923            2.48894;2.59957                     NaN      62110872
# 1187           2.65139;7.50893                     NaN      88886358
# 2607           5.03764;5.91545                     NaN      55860117
# 2862           9.46975;6.06178                     NaN     110277468
# 3330           5.32714;4.40742                     NaN      96748259
# 3996           4.89838;6.22329                     NaN      73058268
# 4280            4.7725;9.36389                     NaN      97323288
# 4381           4.84809;5.36346                     NaN     102980900
# 5293           7.68799;2.60943                     NaN      68004184
# 5979           5.83095;4.41371                     NaN      24998467
# 6085           6.33438;4.07766                     NaN      44734499
# 6244           8.15859;7.36209                     NaN      16355779
# 6595   10.3512;4.81627;6.22329                     NaN      74711742
# 6895           3.18167;6.52951                     NaN     131171405
# 7275           3.18167;8.32512                     NaN      27372032
# 8072           5.53876;3.64327                     NaN      87229783
# 8510   3.71087;3.37221;2.44856                     NaN     139823220
# 9181   5.53799;5.15009;5.21074                     NaN     119669673
# 9294           4.24222;3.95327                     NaN     131439588
# 9711           9.90158;3.10825                     NaN      65381113
# 9745   6.48286;3.69882;3.35749                     NaN      77244010
# 11632          4.92469;4.92361                     NaN     108950125
# 12296              6.3;3.72835                     NaN      98601049
# 12510          3.70989;2.88665                     NaN     123677978
# 12612          7.01347;5.27279                     NaN      52744212
# 12797          3.18458;3.75447                     NaN     159413536
# 12819          3.28488;4.05905                     NaN     168122898
#
#        region_end
# 10        6359527
# 41       17092057
# 869      52027770
# 923      62112095
# 1187     88886677
# 2607     55861270
# 2862    110279174
# 3330     96748526
# 3996     73058926
# 4280     97323855
# 4381    102981933
# 5293     68004493
# 5979     24999344
# 6085     44735586
# 6244     16356888
# 6595     74712468
# 6895    131171796
# 7275     27372387
# 8072     87230696
# 8510    139824305
# 9181    119672013
# 9294    131440969
# 9711     65382369
# 9745     77245226
# 11632   108951716
# 12296    98601676
# 12510   123678792
# 12612    52744903
# 12797   159414395
# 12819   168123872

# %%
endo_only_df
# Out:
#                   chr  start   end  exo_signal  endo_signal  enrichment  \
# 12517  chrUn_GL456370   1485  1737         0.0    97.139428         0.0
#
#        pvalue binding_type  significant  exo_replicates_with_signal  \
# 12517     1.0    endo_only        False                           0
#
#        endo_replicates_with_signal exo_replicate_signals  \
# 12517                            2           0.0,0.0,0.0
#
#                         endo_replicate_signals  region_length  cpg_length  \
# 12517  0.0,196.62691666452508,94.7913680386125            285         252
#
#       cpg_score  cpg_name  exo_replicates_with_peaks  \
# 12517      CpG:       585                          0
#
#        endo_replicates_with_peaks exo_peak_scores_by_rep  \
# 12517                           2                    NaN
#
#       endo_peak_scores_by_rep  region_start  region_end
# 12517         7.41735;15.7784          1571        1856
